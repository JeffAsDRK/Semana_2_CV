# %%
from models import UNet, TransferSegmentation, save_model, load_model
import torch 
import torch.nn as nn 
from torchvision.transforms import v2 
from utils import load_data
import torch.utils.tensorboard as tb 
import numpy as np

torch.manual_seed(17)

DATASET_PATH = 'flood_area_dataset'

def calculate_iou(predicted_mask, target_mask, epsilon=1e-6):
    predicted_mask = torch.sigmoid(predicted_mask) # probabilidades

    predicted_mask = (predicted_mask > 0.5).float() # matriz true/false -> 1/0

    predicted_mask = predicted_mask.view(-1).bool() # permite hacer operacion & y |
    target_mask = target_mask.view(-1).bool()

    intersection = (predicted_mask & target_mask).float().sum()
    union = (predicted_mask | target_mask).float().sum()

    iou = (intersection+epsilon)/(union+epsilon)

    return iou.item()

# %%
import datetime 

train_logger = None 
log_dir = f'semantic_segmentation/runs/{datetime.datetime.now().strftime("%Y%m%d-%H%M%S")}' 

if log_dir:
    from os import path 
    train_logger = tb.SummaryWriter(path.join(log_dir), 'train', flush_secs=1)

# %%
'''model = UNet()'''
model = TransferSegmentation(n_classes=1)
transform = v2.Compose([
    v2.ToImage(),
    v2.ToDtype(torch.float32, scale=True),
    v2.CenterCrop(1000), # desde de la imagen, corto 1000 pixeles hacia afuera, padding=0
    v2.Resize((224, 224))
])
#transform = model.weights.transforms() # resulta mejor con la transformacion propia

train_loader = load_data(dataset_path=DATASET_PATH, transform=transform, batch_size=64)

device = 'cuda' if torch.cuda.is_available() else 'cpu'
model.to(device)

criterion = nn.BCEWithLogitsLoss() # aplica sigmoid directamente sobre los logits del modelo
optimizer = torch.optim.Adagrad(model.parameters(), lr=0.001)
scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer, mode='max')

# %%
# Training Loop
best_iou = 0
num_epochs = 100
i = 0
patience = 0
max_patience = 15

for epoch in range(num_epochs):
    running_loss = 0
    epoch_mean_iou = []

    for (inputs, targets) in train_loader:
        inputs = inputs.to(device)
        targets = targets.to(device)

        outputs = model(inputs)
        loss = criterion(outputs, targets)

        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        batch_iou = calculate_iou(outputs, targets)
        epoch_mean_iou.append(batch_iou)

        running_loss += loss.item()

        if log_dir is not None:
            train_logger.add_images('image', inputs[:6], i)
            train_logger.add_images('label', targets[:6], i)
            train_logger.add_images('pred', torch.sigmoid(outputs[:6])>0.5, i)
        
            if i==0:
                train_logger.add_graph(model, inputs) # representacion grafica del modelo
            i += 1
        
    # Epoch Estadisticas
    epoch_mean_iou = np.mean(epoch_mean_iou)*100
    epoch_loss = running_loss / len(train_loader)

    scheduler.step(epoch_mean_iou)

    if log_dir is not None:
        train_logger.add_scalar('epoch_mean_iou', epoch_mean_iou, epoch)
        train_logger.add_scalar('epoch_loss', epoch_loss, epoch)
        train_logger.add_scalar('epoch_lr', optimizer.param_groups[0]['lr'], epoch)
    
    print(f"Epoch {epoch+1}/{num_epochs} Loss: {epoch_loss:.2f} Mean IoU: {epoch_mean_iou:.2f}%")

    if epoch_mean_iou > best_iou:
        best_iou = epoch_mean_iou
        save_model(model, 'TransferSegmentation.th')
        patience = 0
    else:
        patience += 1
    
    if patience == max_patience:
        break
# Out:
# Epoch 1/100 Loss: 0.55 Mean IoU: 49.88%
# Epoch 2/100 Loss: 0.41 Mean IoU: 63.52%
# Epoch 3/100 Loss: 0.35 Mean IoU: 68.14%
# Epoch 4/100 Loss: 0.32 Mean IoU: 71.93%
# Epoch 5/100 Loss: 0.31 Mean IoU: 73.69%
# Epoch 6/100 Loss: 0.30 Mean IoU: 76.00%
# Epoch 7/100 Loss: 0.29 Mean IoU: 76.54%
# Epoch 8/100 Loss: 0.28 Mean IoU: 78.11%
# Epoch 9/100 Loss: 0.27 Mean IoU: 77.69%
# Epoch 10/100 Loss: 0.27 Mean IoU: 77.72%
# Epoch 11/100 Loss: 0.26 Mean IoU: 79.87%
# Epoch 12/100 Loss: 0.25 Mean IoU: 80.90%
# Epoch 13/100 Loss: 0.25 Mean IoU: 80.26%
# Epoch 14/100 Loss: 0.25 Mean IoU: 80.97%
# Epoch 15/100 Loss: 0.24 Mean IoU: 81.44%
# Epoch 16/100 Loss: 0.24 Mean IoU: 81.95%
# Epoch 17/100 Loss: 0.24 Mean IoU: 81.90%
# Epoch 18/100 Loss: 0.23 Mean IoU: 83.07%
# Epoch 19/100 Loss: 0.23 Mean IoU: 82.65%
# Epoch 20/100 Loss: 0.23 Mean IoU: 83.30%
# Epoch 21/100 Loss: 0.22 Mean IoU: 84.16%
# Epoch 22/100 Loss: 0.22 Mean IoU: 83.78%
# Epoch 23/100 Loss: 0.22 Mean IoU: 84.27%
# Epoch 24/100 Loss: 0.22 Mean IoU: 84.91%
# Epoch 25/100 Loss: 0.21 Mean IoU: 85.06%
# Epoch 26/100 Loss: 0.22 Mean IoU: 83.44%
# Epoch 27/100 Loss: 0.21 Mean IoU: 85.11%
# Epoch 28/100 Loss: 0.21 Mean IoU: 84.96%
# Epoch 29/100 Loss: 0.21 Mean IoU: 85.46%
# Epoch 30/100 Loss: 0.20 Mean IoU: 85.77%
# Epoch 31/100 Loss: 0.20 Mean IoU: 85.25%
# Epoch 32/100 Loss: 0.20 Mean IoU: 86.31%
# Epoch 33/100 Loss: 0.20 Mean IoU: 85.25%
# Epoch 34/100 Loss: 0.20 Mean IoU: 86.25%
# Epoch 35/100 Loss: 0.19 Mean IoU: 86.63%
# Epoch 36/100 Loss: 0.19 Mean IoU: 86.63%
# Epoch 37/100 Loss: 0.19 Mean IoU: 86.50%
# Epoch 38/100 Loss: 0.19 Mean IoU: 86.94%
# Epoch 39/100 Loss: 0.19 Mean IoU: 87.19%
# Epoch 40/100 Loss: 0.19 Mean IoU: 86.54%
# Epoch 41/100 Loss: 0.19 Mean IoU: 87.72%
# Epoch 42/100 Loss: 0.18 Mean IoU: 87.09%
# Epoch 43/100 Loss: 0.18 Mean IoU: 86.94%
# Epoch 44/100 Loss: 0.18 Mean IoU: 88.08%
# Epoch 45/100 Loss: 0.18 Mean IoU: 87.36%
# Epoch 46/100 Loss: 0.18 Mean IoU: 86.66%
# Epoch 47/100 Loss: 0.18 Mean IoU: 87.86%
# Epoch 48/100 Loss: 0.17 Mean IoU: 88.04%
# Epoch 49/100 Loss: 0.17 Mean IoU: 88.07%
# Epoch 50/100 Loss: 0.17 Mean IoU: 88.06%
# Epoch 51/100 Loss: 0.17 Mean IoU: 88.01%
# Epoch 52/100 Loss: 0.17 Mean IoU: 88.79%
# Epoch 53/100 Loss: 0.17 Mean IoU: 88.48%
# Epoch 54/100 Loss: 0.17 Mean IoU: 87.74%
# Epoch 55/100 Loss: 0.17 Mean IoU: 88.38%
# Epoch 56/100 Loss: 0.17 Mean IoU: 88.20%
# Epoch 57/100 Loss: 0.16 Mean IoU: 88.94%
# Epoch 58/100 Loss: 0.17 Mean IoU: 88.32%
# Epoch 59/100 Loss: 0.16 Mean IoU: 88.05%
# Epoch 60/100 Loss: 0.17 Mean IoU: 88.56%
# Epoch 61/100 Loss: 0.16 Mean IoU: 88.16%
# Epoch 62/100 Loss: 0.17 Mean IoU: 87.69%
# Epoch 63/100 Loss: 0.16 Mean IoU: 88.85%
# Epoch 64/100 Loss: 0.16 Mean IoU: 88.49%
# Epoch 65/100 Loss: 0.16 Mean IoU: 88.64%
# Epoch 66/100 Loss: 0.16 Mean IoU: 88.49%
# Epoch 67/100 Loss: 0.16 Mean IoU: 89.40%
# Epoch 68/100 Loss: 0.15 Mean IoU: 88.72%
# Epoch 69/100 Loss: 0.16 Mean IoU: 88.65%
# Epoch 70/100 Loss: 0.15 Mean IoU: 88.99%
# Epoch 71/100 Loss: 0.15 Mean IoU: 89.04%
# Epoch 72/100 Loss: 0.15 Mean IoU: 89.32%
# Epoch 73/100 Loss: 0.15 Mean IoU: 88.84%
# Epoch 74/100 Loss: 0.15 Mean IoU: 88.55%
# Epoch 75/100 Loss: 0.15 Mean IoU: 88.73%
# Epoch 76/100 Loss: 0.15 Mean IoU: 89.48%
# Epoch 77/100 Loss: 0.15 Mean IoU: 88.96%
# Epoch 78/100 Loss: 0.15 Mean IoU: 88.82%
# Epoch 79/100 Loss: 0.15 Mean IoU: 88.91%
# Epoch 80/100 Loss: 0.15 Mean IoU: 88.85%
# Epoch 81/100 Loss: 0.15 Mean IoU: 88.87%
# Epoch 82/100 Loss: 0.15 Mean IoU: 88.84%
# Epoch 83/100 Loss: 0.15 Mean IoU: 88.82%
# Epoch 84/100 Loss: 0.15 Mean IoU: 88.91%
# Epoch 85/100 Loss: 0.14 Mean IoU: 89.24%
# Epoch 86/100 Loss: 0.14 Mean IoU: 89.23%
# Epoch 87/100 Loss: 0.14 Mean IoU: 88.80%
# Epoch 88/100 Loss: 0.14 Mean IoU: 89.43%
# Epoch 89/100 Loss: 0.14 Mean IoU: 89.53%
# Epoch 90/100 Loss: 0.14 Mean IoU: 89.54%
# Epoch 91/100 Loss: 0.14 Mean IoU: 89.34%
# Epoch 92/100 Loss: 0.14 Mean IoU: 89.23%
# Epoch 93/100 Loss: 0.14 Mean IoU: 89.40%
# Epoch 94/100 Loss: 0.14 Mean IoU: 89.70%
# Epoch 95/100 Loss: 0.14 Mean IoU: 89.49%
# Epoch 96/100 Loss: 0.14 Mean IoU: 89.41%
# Epoch 97/100 Loss: 0.14 Mean IoU: 89.30%
# Epoch 98/100 Loss: 0.14 Mean IoU: 89.09%
# Epoch 99/100 Loss: 0.14 Mean IoU: 89.66%
# Epoch 100/100 Loss: 0.14 Mean IoU: 89.14%
